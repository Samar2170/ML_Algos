# %%
import requests
from bs4 import BeautifulSoup as bs

# %%
import pandas as pd

# %%
res = requests.get('https://www.moneycontrol.com/india/stockpricequote/refineries/relianceindustries/RI')

# %%
soup = bs(res.content,'lxml')

# %%
import re
pl_link = bs_link = soup.find_all('a',href=re.compile('profit-loss'))

# %%
pl_link
# Out:
# [<a href="https://www.moneycontrol.com/financials/relianceindustries/profit-lossVI/RI#RI" target="_blank" title="Profit &amp; Loss">Profit &amp; Loss</a>,
#  <a href="https://www.moneycontrol.com/financials/relianceindustries/profit-lossVI/RI#RI" target="_blank" title="Profit &amp; Loss">Profit &amp; Loss</a>]

# %%
pl = pl_link[0]
pl = pl['href']
res = requests.get(pl)

# %%
df = pd.read_html(res.content)

# %%
df = df[0]

# %%
df.columns = df.iloc[0]
df.head()
# Out:
# 0 Profit & Loss account of Reliance Industries (in Rs. Cr.)    Mar 21  \
# 0  Profit & Loss account of Reliance Industries (...           Mar 21
# 1                                                NaN          12 mths
# 2                                             INCOME              NaN
# 3                    Revenue From Operations [Gross]         265069.0
# 4               Less: Excise/Sevice Tax/Other Levies          19402.0
#
# 0    Mar 20    Mar 19    Mar 18    Mar 17  NaN
# 0    Mar 20    Mar 19    Mar 18    Mar 17  NaN
# 1   12 mths   12 mths   12 mths   12 mths  NaN
# 2       NaN       NaN       NaN       NaN  NaN
# 3  365202.0  401583.0  315357.0  265041.0  NaN
# 4   29224.0   29967.0   25315.0   23016.0  NaN

# %%
df.set_index('Profit & Loss account of Reliance Industries (in Rs. Cr.)', inplace=True)

# %%
df.index = df.index.str.replace(" ","")

# %%
df.head()
# Out:
# 0                                                     Mar 21    Mar 20  \
# Profit & Loss account of Reliance Industries (i...
# Profit&LossaccountofRelianceIndustries(inRs.Cr.)      Mar 21    Mar 20
# NaN                                                  12 mths   12 mths
# INCOME                                                   NaN       NaN
# RevenueFromOperations[Gross]                        265069.0  365202.0
# Less:Excise/SeviceTax/OtherLevies                    19402.0   29224.0
#
# 0                                                     Mar 19    Mar 18  \
# Profit & Loss account of Reliance Industries (i...
# Profit&LossaccountofRelianceIndustries(inRs.Cr.)      Mar 19    Mar 18
# NaN                                                  12 mths   12 mths
# INCOME                                                   NaN       NaN
# RevenueFromOperations[Gross]                        401583.0  315357.0
# Less:Excise/SeviceTax/OtherLevies                    29967.0   25315.0
#
# ...

# %%
df.columns = df.columns.fillna('to_drop')
df.drop('to_drop',axis=1, inplace=True)
df.head()
# Out:
# 0                                                     Mar 21    Mar 20  \
# Profit & Loss account of Reliance Industries (i...
# Profit&LossaccountofRelianceIndustries(inRs.Cr.)      Mar 21    Mar 20
# NaN                                                  12 mths   12 mths
# INCOME                                                   NaN       NaN
# RevenueFromOperations[Gross]                        265069.0  365202.0
# Less:Excise/SeviceTax/OtherLevies                    19402.0   29224.0
#
# 0                                                     Mar 19    Mar 18  \
# Profit & Loss account of Reliance Industries (i...
# Profit&LossaccountofRelianceIndustries(inRs.Cr.)      Mar 19    Mar 18
# NaN                                                  12 mths   12 mths
# INCOME                                                   NaN       NaN
# RevenueFromOperations[Gross]                        401583.0  315357.0
# Less:Excise/SeviceTax/OtherLevies                    29967.0   25315.0
#
# ...

# %%
df.fillna(0.2376,inplace=True)
df.head()
# Out:
# 0                                                     Mar 21    Mar 20  \
# Profit & Loss account of Reliance Industries (i...
# Profit&LossaccountofRelianceIndustries(inRs.Cr.)      Mar 21    Mar 20
# NaN                                                  12 mths   12 mths
# INCOME                                                0.2376    0.2376
# RevenueFromOperations[Gross]                        265069.0  365202.0
# Less:Excise/SeviceTax/OtherLevies                    19402.0   29224.0
#
# 0                                                     Mar 19    Mar 18  \
# Profit & Loss account of Reliance Industries (i...
# Profit&LossaccountofRelianceIndustries(inRs.Cr.)      Mar 19    Mar 18
# NaN                                                  12 mths   12 mths
# INCOME                                                0.2376    0.2376
# RevenueFromOperations[Gross]                        401583.0  315357.0
# Less:Excise/SeviceTax/OtherLevies                    29967.0   25315.0
#
# ...

# %%
co_df = pd.read_csv('map_bs/nifty500list.csv')
co_df['Company Name'] = co_df['Company Name'].str.replace(" Ltd.","")
# Out:
# <ipython-input-26-1259993a5be4>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   co_df['Company Name'] = co_df['Company Name'].str.replace(" Ltd.","")

# %%
co_df
# Out:
#                              Company Name                           Industry  \
# 0                                3M India                     CONSUMER GOODS
# 1                               ABB India           INDUSTRIAL MANUFACTURING
# 2    ABB Power Products and Systems India           INDUSTRIAL MANUFACTURING
# 3                                     ACC           CEMENT & CEMENT PRODUCTS
# 4                         AIA Engineering           INDUSTRIAL MANUFACTURING
# ..                                    ...                                ...
# 496                              Yes Bank                 FINANCIAL SERVICES
# 497         Zee Entertainment Enterprises  MEDIA ENTERTAINMENT & PUBLICATION
# 498                    Zensar Technolgies                                 IT
# 499                        Zydus Wellness                     CONSUMER GOODS
# 500                       eClerx Services                                 IT
#
#          Symbol Series     ISIN Code
# ...

# %%
import requests
headers = {
        'user-agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36',
    }
res = requests.get('https://www.topstockresearch.com/index/BSE_500.html', headers=headers)
df = pd.read_html(res.content)

# %%
df[2]
# Out:
#                                                   Name  \
#                                                   Name
# 0                                  3I INFOTECH LIMITED
# 1                                        3M India Ltd.
# 2                           63 Moons Technologies Ltd.
# 3                                   Aban Offshore Ltd.
# 4                                             ABB Ltd.
# ..                                                 ...
# 100                                  DEN Networks Ltd.
# 101                                          Dena Bank
# 102                             Dhanalakshmi Bank Ltd.
# 103  (adsbygoogle = window.adsbygoogle || []).push(...
# 104                 Page 1 Page 2 Page 3 Page 4 Page 5
#
#                                            Close Price  \
#                                            Close Price
# 0                                                 4.75
# 1                                              14034.2
# ...

# %%
res = requests.get(pl)

# %%
df = pd.read_html(res.content)
df = df[0]
df.head()
# Out:
#                                                    0         1         2  \
# 0  Profit & Loss account of Reliance Industries (...    Mar 21    Mar 20
# 1                                                NaN   12 mths   12 mths
# 2                                             INCOME       NaN       NaN
# 3                    Revenue From Operations [Gross]  265069.0  365202.0
# 4               Less: Excise/Sevice Tax/Other Levies   19402.0   29224.0
#
#           3         4         5   6
# 0    Mar 19    Mar 18    Mar 17 NaN
# 1   12 mths   12 mths   12 mths NaN
# 2       NaN       NaN       NaN NaN
# 3  401583.0  315357.0  265041.0 NaN
# 4   29967.0   25315.0   23016.0 NaN

# %%
df.at[0,0]
# Out:
# 'Profit & Loss account of Reliance Industries (in Rs. Cr.)'

# %%
df.at[0,0] = "Metrics"
df.head()
# Out:
#                                       0         1         2         3  \
# 0                               Metrics    Mar 21    Mar 20    Mar 19
# 1                                   NaN   12 mths   12 mths   12 mths
# 2                                INCOME       NaN       NaN       NaN
# 3       Revenue From Operations [Gross]  265069.0  365202.0  401583.0
# 4  Less: Excise/Sevice Tax/Other Levies   19402.0   29224.0   29967.0
#
#           4         5   6
# 0    Mar 18    Mar 17 NaN
# 1   12 mths   12 mths NaN
# 2       NaN       NaN NaN
# 3  315357.0  265041.0 NaN
# 4   25315.0   23016.0 NaN

# %%
df.head()
# Out:
#                                                    0         1         2  \
# 0  Profit & Loss account of Reliance Industries (...    Mar 21    Mar 20
# 1                                                NaN   12 mths   12 mths
# 2                                             INCOME       NaN       NaN
# 3                    Revenue From Operations [Gross]  265069.0  365202.0
# 4               Less: Excise/Sevice Tax/Other Levies   19402.0   29224.0
#
#           3         4         5   6
# 0    Mar 19    Mar 18    Mar 17 NaN
# 1   12 mths   12 mths   12 mths NaN
# 2       NaN       NaN       NaN NaN
# 3  401583.0  315357.0  265041.0 NaN
# 4   29967.0   25315.0   23016.0 NaN

# %%
res= requests.get('https://www.moneycontrol.com/india/stockpricequote/finance-investments/adityabirlacapital/ABC9')

# %%
soup = bs(res.content,'lxml')

# %%
divv = soup.find('div', id='company_info')
divv
# Out:
# <div id="company_info">
# <div class="common_heading"><h2>About the Company</h2></div>
# <div class="clearfix">
# <!-- <h2 class="shhold_head">COMPANY OVERVIEW</h2> -->
# </div>
# <div class="com_overviewcnt">
# <div class="morepls_cnt">Aditya Birla Financial Services Group (ABFSG) is an umbrella brand for all the financial service businesses of the Aditya Birla Group. They have a significant presence across life insurance, asset management, NBFC, infrastructure project and structured finance, private equity, broking, wealth management and distribution, online money management, and general insurance advisory services.</div>
# </div>
# ...

# %%
lis = divv.find_all('li',class_='clearfix')

# %%
import re
sym = divv.find('span', string=re.compile('NSE:'))
sym.get_text()
# Out:
# 'NSE:'

# %%
ul = soup.find_all('ul', class_='comdetl')

# %%
ul = ul[-1]

# %%
sym = ul.find_all('li')

# %%
sym[1].p.get_text()
# Out:
# 'ABCAPITAL'
